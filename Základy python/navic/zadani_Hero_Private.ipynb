# %% [markdown]
# **Vytvořte Třídu typ(Enum), která Vám dá na výběr, který typ předmětu budete moc vybrat níže**

# %%
from enum import Enum
import random as rand
class Typ(Enum):
    ZBRAN = "Zbraň"

# %% [markdown]
# **Vytvořte Třídu Předmět, která bude obsahovat atributy:**
#
#
# 1. Název
# 2. typ (typ předmětu: zbraň, poťák, brnění...)
# 3. životy
# 4. min útok
# 5. max útok
# 6. obrana (armor)
# 8. vaha
#
# **Vytvořte metody:**
# 1. ToString
# 2. atribut typ, přijímá třídu Typ(Enum)

# %%
class Predmet:
    def __init__(self, nazev, typ_predmetu:Typ,hp, min_utok, max_utok, obrana,vaha):
        self.__nazev = nazev
        self.__hp = hp
        self.__typ_predmetu = typ_predmetu
        self.__min_utok = min_utok
        self.__max_utok = max_utok
        self.__obrana = obrana
        self.__vaha = vaha

# %%
p1 = Predmet("Meč",Typ.ZBRAN,20,3,6,0,5)
print(p1)

# %% [markdown]
# Náhled výstupu
# ```
# ___________________________
#
# Staty Předmětu: Meč
#     Typ předmětu: Zbraň
#     Váha: 5
#     HP: 20
#     Obrana: 0
#     útok: 3-6
# ```

# %% [markdown]
# **Vytvořte Třídu Baťoh, která bude obsahovat atributy:**
#
# 1. Předměty
# 2. Celková váha
# 3. Maximální váha
#
# **Dále obsahuje metody**
#
# 1.   getPredmety, getCelkovaVaha, getMaximum, predmetyToString
# 2.   setMaximum, addPredmet, removePredmet, ToString
#
# Pokud přidáte do batohu větší váhu než je jeho maximální váha, předmět se nepřidá

# %%
class Batoh:
    def __init__(self, maximum):
        self.__predmety = [] # seznam všech předmětů uvnitř
        self.__celkovaVaha = 0 # celkova vaha, která je uvnitř
        self.__maximalniNosnost = max(10,maximum) # unesu vždy minimálně 10kg

# %% [markdown]
# **Vytvořte Třídu Equip, která dědí od třídy Batoh, ale neřeší váhu a nosnost**
#
# 1. Předměty
#
#
# **Obsahuje metody**
#
# 1.   getPredmety, predmetyToString, ToString
# 2.   addPredmet, removePredmet
#
# Pokud přidáte do batohu větší váhu než je jeho maximální váha, předmět se nepřidá

# %%
class Equip(Batoh):

# %%
#Zde vytvořte batoh a zkuste do něj přidat vypsat a odebrat předmět
batoh = Batoh(25)
batoh.addPredmet(p1)
batoh.addPredmet(p1)
print(batoh)
print(batoh.vypisVsechnyInformace())
batoh.removePredmet(p1)
print(batoh)
batoh.removePredmet(p1)
batoh.removePredmet(p1)
print(batoh)

# %% [markdown]
# Ukázka řešení
#
# ```
# 'Meč' byl přidán do batohu
# 'Meč' byl přidán do batohu
# Obsazeno v batohu 10/25.
# V batohu máš:
# Meč, Meč,
#
# Obsazeno v batohu 10/25. V batohu máš:
# 1. předmět v batohu
# ___________________________
#
# Staty Předmětu: Meč
#     Typ předmětu: Zbraň
#     Váha: 5
#     HP: 20
#     Obrana: 0
#     útok: 3-6
#
#
# 2. předmět v batohu
# ___________________________
#
# Staty Předmětu: Meč
#     Typ předmětu: Zbraň
#     Váha: 5
#     HP: 20
#     Obrana: 0
#     útok: 3-6
#
#
#
# Predmět Meč byl odebrán z batohu.
# Obsazeno v batohu 5/25.
# V batohu máš:
# Meč,
#
# Predmět Meč byl odebrán z batohu.
# Předmět se v batohu nenachází
# Obsazeno v batohu 0/25. V batohu nic nemáš
# ```

# %% [markdown]
# **Vytvořte Třídu Hrdina, která bude obsahovat atributy:**
#
# 1. Jmeno
# 2. HP
# 3. min utok
# 4. max utok
# 5. obrana
# 6. maximalni nosnost (lze vyřešit batohem: nemusí být)
# 7. armorCapacity = 1
# 8. helmaCapacity = 1
# 9. weaponCapacity = 2
# 10. Baťoh: Batoh
# 11. Equip: Equip
#
# **Dále obsahuje metody**
#
# 1.   nastavte get či set
# 2.   přidejte další vhodné metody
#
# * Pokud přidáte do batohu předmět, který hrdina již neunese. Předmět se nepřidá.
# * Pokud budete chtít obléct armor, ale již jeden máte musíte původní odložit na zem či do baťohu. atd.

# %%
class Hrdina:
    def __init__(self, jmeno, hp, min_utok, max_utok, obrana, max_nosnost):
        self.__jmeno = jmeno
        self.__hp = hp
        self.__min_utok = min_utok
        self.__max_utok = max_utok
        self.__obrana = obrana
        self.__armorCapacity = 1
        self.__helmaCapacity = 1
        self.__weaponCapacity = 2
        self.__batoh = Batoh(max_nosnost)
        self.__equip = Equip()

    # další metody, které hrdina umí
    def updateStatu(self, predmet):
        pass

    def updateStatuOdloz(self, predmet):
        pass


    def utok(self, enemy):
       pass

    def seber(self, predmet):
       pass

    def odloz(self, predmet):
       pass

    def pouzij(self, predmet):
        pass

    def oblec(self, predmet):
       pass

# %%
#Zde si zkuste vytvořit hrdinu a zkuste na něm všechny metody
hero = Hrdina("Honza",50,1,3,5,25)
enemy = Hrdina("Goblin",20,1,3,1,25)
hero.seber(p1)
hero.seber(p1)
print(hero)
hero.oblec(p1)
hero.oblec(p1)
hero.oblec(p1)
print(hero)
hero.utok([enemy])
enemy.utok([hero])
hero.utok([enemy])
enemy.utok([hero])

# %% [markdown]
# ukázka řešení
# ```
# 'Meč' byl přidán do batohu
# Tento Předmět již máte
#
# ___________________________
#
# Staty: Honza
#     HP: 50
#     Obrana: 5
#     utok: 1-3
#     Batoh: Meč,
#     Equip:
#
# 'Meč' byl obléknut
# Jednoruční zbraň nandána
# Tento předmět již máš na sobě
# Tento předmět již máš na sobě
#
# ___________________________
#
# Staty: Honza
#     HP: 70
#     Obrana: 5
#     utok: 4-9
#     Batoh: Meč,
#     Equip: Meč,
#
# Honza útočí na Goblin za: 5 - 1 = 4
# Goblin zůstalo: 16
# Goblin útočí na Honza za: 2 - 5 = 1
# Honza zůstalo: 69
# Honza útočí na Goblin za: 5 - 1 = 4
# Goblin zůstalo: 12
# Goblin útočí na Honza za: 3 - 5 = 1
# Honza zůstalo: 68
# ```

# %% [markdown]
# **Vytvořte třídu Nepřítel, která dědí od Hrdiny**
# Přepište konstruktor (metodu init) a metodu ToString (str) tak, aby nepřítel mohl dropovat některý z předmětů, který mu dáte

# %%
class Nepritel(Hrdina):

# %% [markdown]
# Níže vytvořte hrdinu, 5 různých předmětů, 3 různé nepřátele.

# %%
#TODO Váš kód
klic = Predmet("Klíč_k_Boos_roomce",Typ.BEZNA,0,0,0,0,0)
goblin = Nepritel("Goblin",15,1,6,5,25)
goblinSKlicem = Nepritel("Goblin s klíčem",15,1,6,5,25,klic)
print(goblin)
print(goblinSKlicem)

# %% [markdown]
# Ukázka nepřítele s a bez itemu
#
#
# ```
#
#
#
# _____________________
#
# Staty: Goblin
#     HP: 15
#     Obrana: 5
#     utok: 1-6
#     Batoh:
#     Equip:
#
#
# ___________________________
#
# Staty: Goblin s klíčem
#     HP: 15
#     Obrana: 5
#     utok: 1-6
#     Batoh: Klíč_k_Boos_roomce,
#     Equip:
# ```

# %% [markdown]
# **Vytvořte Třídu Room, která bude obsahovat atributy:**
#
# 1. název
# 2. seznamExitu
# 3. poklad
# 4. nepritel
#
# **Vytvořte metody:**
#
# 1.   getNazev, setNazev, getExity, getPoklad, getNepritel, toString
# 2.   addExit, addPredmet, removePredmet
# 3.   exityToString, neprateleToString, pokladyToString()

# %%
class Room:
    def __init__(self, nazev, nepritel=None, predmet=None):
        pass

# %% [markdown]
# **Zde je vytvořená jednoduchá mapa s výpisy**

# %%
#TODO

# %% [markdown]
# Ukázka řešení
#
# ```
# Nacházíš se v Vyhlídka
# Můžeš se vydat do: Vstup_do_jeskyně, Dračí_slůj,
# ########################################################
# Seznam předmětů v místnosti: Klíč_k_Boos_roomce,
# ########################################################
# Seznam nepřátel v místnosti: Goblin s klíčem,
# Nacházíš se v Vstup_do_jeskyně
# Můžeš se vydat do: Vyhlídka, Jezírko, Dračí_slůj,
# ########################################################
# Seznam předmětů v místnosti:
# ########################################################
# Seznam nepřátel v místnosti:
# ```

# %% [markdown]
# **Zde vytvořte třídu Prikaz, která bude obsahovat vaše příkazy**
# Vstupem do této třídy je:
# * příkaz (to co jsem zadal do konzole)
# * místnost (v jaké se nacházím)
# * hrdina
#
# také metody
# *   getHero
# *   getMistnost
# *   setMistnost
#
# Třída bude obsahovat tyto možnosti.
# *   jdi
# *   seber
# *   polož
# *   obleč
# *   útok
# *   help (vypíše co všechno hrdina může udělat)
# *   info (informace o mistnosti: vše co v ní je)
# *   moreInfo (to samé co info, ale podrobně) print(room.vypisVsechnyInformace())
# *   staty (staty hrdiny)
# *   provedPrikaz(prikaz) (ta zavolá takovou metodu, podle slova v commandu čili (příkaz "útok" zavolá metodu "utok"

# %%
class Prikaz:
    def __init__(self, prikaz, mistnost, hrdina):
        self.prikaz = prikaz
        self.__mistnost = mistnost
        self.__hrdina = hrdina

# %% [markdown]
# **Zde vytvořte třídu ExecuteCommand**
# Vstupem do této třídy je:
# * místnost (v jaké se nacházím)
# * hrdina
#
# Třída bude obsahovat tyto možnosti.
# *   getHero
# *   getCurrentRoom
# *   setCurrentRoom(room)
# *   execute(command) metoda obsahuje třídu Prikaz, která provede daný příkaz napsaný v zadání While níže

# %%
class ExecuteCommand:
    def __init__(self, hero, initial_room):
        self.__hero = hero
        self.__currentRoom = initial_room

# %% [markdown]
# **Zde vytvoř while, který bude přijímat příkazy a na základě nich dělat akce hrdiny.**
# Vymyslete jendoduchý úvod do příběhu a zařiďte že hra skončí smrtí hrdiny i smrtí bosse hry

# %%
#TODO
while True:
    executor = ExecuteCommand("hero", "aktualniMistnost") # založení toho co nám zpracovává příkazy
    executor.execute("help") #zavolán příkaz HELP
